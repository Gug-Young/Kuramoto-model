# %%
import cupy as cp

# %%
# %timeit cp.random.rand(1000,100)
# Out:
# 27.2 µs ± 409 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import numpy as np

# %%
# %timeit np.random.rand(1000,100)
# Out:
# 504 µs ± 1.13 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
address = 'http://url.kr/mjq5wh'
data = np.loadtxt(address)
H_data=data
# 사진찍고 다시해보자
eps =1e-5;c=0.01;H=10.0 #수렴하지 않으면 계속 바꿔가면서 하면 된다.
dH = 0.001
x=H_data[:,0];y=H_data[:,1]
def f(x,H):return (H*x)
def E(x,y,H): return np.sum((y-f(x,H))**2)
Sxy=np.sum(x*y)
Sxx=np.sum(x*x)

# dH = 1
num = 0
while (np.abs(dH) >eps):
    dEdH=(E(x,y,H+dH)-E(x,y,H))/dH
    deltaH=-c*dEdH
    H+=deltaH
    num +=1
    # if num%100 == 0:
    
    print(H)
plt.plot(x,y,"x")
plt.plot(x,H*x)
# Out:
# 596.632983237505
# 483.15352573641576
# 505.10521895310376
# 500.8588395145489
# 501.680267645861
# 501.52136894495925
# 501.552106627787
# 501.54616066865856
# 501.5473108662991
# 501.5470883704256
# 501.5471314112074
# 501.5471230846015
# 501.54712469520746
# 501.5471243837965
# 501.54712444375036
# 501.54712443239987
# 501.5471244350192
# 501.547124433564
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# 501.54712443385506
# 501.5471244347282
# ...

# %%
import sympy as sym

# %%
A,L,b = sym.symbols('A L b')
M = sym.symbols('M',cls=sym.Function)
f =M(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\kim9y\Desktop\Kuramoto\Kuramoto-model\Test.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kim9y/Desktop/Kuramoto/Kuramoto-model/Test.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> A,L,b = sym.symbols('A L b')
#       <a href='vscode-notebook-cell:/c%3A/Users/kim9y/Desktop/Kuramoto/Kuramoto-model/Test.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> M = sym.symbols('M',cls=sym.Function)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kim9y/Desktop/Kuramoto/Kuramoto-model/Test.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> f =M(t)
#
# NameError: name 't' is not defined

# %%
eq = sym.diff(A*L**b,b)

# %%
eq
# Out:
# A*L**b*log(L)
