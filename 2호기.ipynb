# %%
import numpy as np
import matplotlib.pyplot as plt
from TO_sim.gen_Distribution import *
from TO_sim.Hysteresis_Kuramoto import *
from TO_sim.To_Draw import *

# %%
t_end = 1000
m = 0.95
N = 5000
dist = "Quantile Lorentzian"
dK = 0.2
dt = 0.1
Ks, t_dic, rs_dic, t_r_dic, rs_r_dic = Hysteresis(m,N=N,dK=dK,t_end=t_end,dist=dist,dt=dt)
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]
#   0%|          | 0/63 [00:00<?, ?it/s]

# %%
Time_R(Ks,t_dic,rs_dic,t_r_dic,rs_r_dic,dK,dt,t_end,N,m,save=True,Folder_name="Review")

# %%
# Multiprocess
from TO_sim.Multi_m import Sim_Multi_mset,Sim_Multi_m_giveNoise
import parmap
for Noise in [30,50]:
    Sim_Multi_mset(Noise)
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]
#   0%|          | 0/63 [00:00<?, ?it/s]
#   0%|          | 0/63 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\kim9y\Desktop\Kuramoto\Kuramoto-model\2호기.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kim9y/Desktop/Kuramoto/Kuramoto-model/2%ED%98%B8%EA%B8%B0.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> import parmap
#       <a href='vscode-notebook-cell:/c%3A/Users/kim9y/Desktop/Kuramoto/Kuramoto-model/2%ED%98%B8%EA%B8%B0.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> for Noise in [30,50]:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kim9y/Desktop/Kuramoto/Kuramoto-model/2%ED%98%B8%EA%B8%B0.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     Sim_Multi_mset(Noise)
#
# File c:\Users\kim9y\Desktop\Kuramoto\Kuramoto-model\TO_sim\Multi_m.py:124, in Sim_Multi_mset(Noise, p_method)
#     122 else:
#     123     omega = Make_Omega(p_method, N, Noise)
# --> 124     theta_s, dtheta_s, omega, rs, t = Sol_Kuramoto_mf(
#     125         N,
#     126         K,
#     127         m,
#     128         (0, t_end),
#     129         dt=dt,
#     130         p_theta=theta_dic[num - 1][-1],
#     131         p_dtheta=dtheta_dic[num - 1][-1],
#     132         p_omega=omega,
#     133         distribution="Normal",
#     134     )
#     135     # theta_s,dtheta_s,omega,rs,t = Sol_Kuramoto_mf(N,K,m,(0,t_end),dt=dt,p_theta=theta_dic[num-1][-1],p_dtheta=dtheta_init,p_omega=omega_dic[num-1],distribution="Normal")
#     136 theta_dic[num] = theta_s
#
# File c:\Users\kim9y\Desktop\Kuramoto\Kuramoto-model\TO_sim\Sol_Kuramoto.py:24, in Sol_Kuramoto_mf(N, K, m, tspan, p_theta, p_dtheta, p_omega, dt, mean, sigma, distribution, seed)
#      21     theta, dtheta, omega  =  p_theta, p_dtheta,p_omega
#      23 t = np.arange(tspan[0],tspan[1]+dt,dt)
# ---> 24 result = RK4(Kuramoto_2nd_mf,np.array([*theta,*dtheta]),t,args=(omega,N,m,K))
#      25 theta_s = result[:,:N]
#      26 dtheta_s = result[:,N:]
#
# File c:\Users\kim9y\Desktop\Kuramoto\Kuramoto-model\TO_sim\Integrator.py:35, in RK4(f, y0, t, args)
#      33 k1 = f(y[i], t[i], *args)
#      34 k2 = f(y[i] + k1 * h / 2.0, t[i] + h / 2.0, *args)
# ---> 35 k3 = f(y[i] + k2 * h / 2.0, t[i] + h / 2.0, *args)
#      36 k4 = f(y[i] + k3 * h, t[i] + h, *args)
#      37 y[i + 1] = y[i] + (h / 6.0) * (k1 + 2 * k2 + 2 * k3 + k4)
#
# File c:\Users\kim9y\Desktop\Kuramoto\Kuramoto-model\TO_sim\Kuramoto_model.py:10, in Kuramoto_2nd_mf(Theta, t, omega, N, m, K)
#       7     psi = np.angle(rpsi)
#       8     return r,psi
# ---> 10 def Kuramoto_2nd_mf(Theta,t,omega,N,m,K):
#      11     if m != 0:
#      12         # print(f"Case m = {m}")
#      13         theta,dtheta = Theta[:N],Theta[N:]
#
# KeyboardInterrupt:
