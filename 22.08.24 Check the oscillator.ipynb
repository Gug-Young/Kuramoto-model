# %%
import numpy as np
import matplotlib.pyplot as plt
from TO_sim.Sol_Kuramoto import *

# %%
theta_s,dtheta_s,omega,rs,t = Sol_Kuramoto_mf(500,3,0.95,(0,100),distribution="Quantile Lorentzian")

# %%
plt.plot(t,rs)

# %%
test = np.random.rand(10,10)

# %%
test = np.random.rand(10,10)
plt.errorbar(np.arange(0,10),np.mean(test,axis=1),yerr = np.std(test,axis=1),fmt = 'd',markersize=4,capsize=3)
test = np.random.rand(10,10)
plt.errorbar(np.arange(0,10),np.mean(test,axis=1),yerr = np.std(test,axis=1),fmt = 'd',markersize=4,capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Check the sort time

# %%
import numpy as np
import matplotlib.pyplot as plt
from TO_sim.gen_Distribution import *
from TO_sim.Hysteresis_Kuramoto import *
from TO_sim.To_Draw import *
from TO_sim.Multi_m import createFolder

# %%
t_end = 1000
m = 6
N = 200
dist = "Quantile Lorentzian"
dK = 0.2
dt = 0.1
Ks, t_dic, rs_dic, t_r_dic, rs_r_dic = Hysteresis(m,N=N,dK=dK,t_end=t_end,dist=dist,dt=dt)
# Out:
# ...
#   0%|          | 0/63 [00:00<?, ?it/s]

# %%
# createFolder(f"Review3/m = {m}")
Time_R(Ks,t_dic,rs_dic,t_r_dic,rs_r_dic,dK,dt,t_end,N,m,mean_time=50,save=False,Folder_name=f"Review3/m = {m}")
# Time_R(Ks,t_dic,rs_dic,t_r_dic,rs_r_dic,dK,dt,t_end,N,m,save=True,Folder_name="Review")
